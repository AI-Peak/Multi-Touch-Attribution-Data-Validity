# %% [markdown]
# # Notebook 01 - RQ1 Data Validity Audit
#
# RQ1 asks whether the dataset is valid enough for direct multi-touch attribution analysis. This notebook reads the pipeline outputs and focuses on conversion-rate plausibility, label construction, and event timing.

# %%
import pandas as pd
validity = pd.read_csv('outputs/rq1_data_validity_summary.csv')
label_audit = pd.read_csv('outputs/rq1_label_event_audit.csv')
benchmarks = pd.read_csv('outputs/rq1_benchmark_conversion_rates.csv')
validity

# %%
label_audit

# %%
benchmarks[['source', 'rate_pct', 'denominator', 'note']]

# %% [markdown]
# ## RQ1 Conclusion
#
# The dataset fails the direct-attribution plausibility check. The current any-Yes rule produces an 83.63% user-level conversion rate, while repeated and non-terminal Yes labels are common. This does not prove the data is useless, but it means channel attribution should be framed as a validity caution rather than a market recommendation.
