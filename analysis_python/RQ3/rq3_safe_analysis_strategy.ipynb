# %% [markdown]
# # Notebook 03 - RQ3 Safe Analysis Strategy
#
# RQ3 asks what analysis is safer when the label is questionable. This notebook summarizes sensitivity labels and the descriptive budget simulation.

# %%
import pandas as pd
stability = pd.read_csv('outputs/rq3_sensitivity_rank_stability.csv')
shares = pd.read_csv('outputs/rq3_sensitivity_channel_shares.csv')
sim = pd.read_csv('outputs/rq3_simulation_results.csv')
stability

# %%
shares.pivot(index='channel', columns='scenario', values='linear_pct')

# %%
sim

# %% [markdown]
# ## RQ3 Conclusion
#
# The safer strategy is to report a validity audit, label sensitivity, and cautious descriptive comparisons. Direct budget optimization claims should be avoided because ranking stability changes under alternative labels and simulated gains are very small.
